# %% [markdown]
# # Genre Classification Project: Data Assessment and Basic EDA
#
# This notebook focuses on the initial steps of the genre classification project using the [Genre Classification Dataset from IMDb](https://www.kaggle.com/datasets/hijest/genre-classification-dataset-imdb).
#
# ## Contents
# 1. **Data Loading and Overview**: Loading the dataset and getting a general understanding of its structure and contents.
# 2. **Data Cleaning**: Identifying and handling missing values, duplicates, and any other data quality issues.
# 3. **Basic Exploratory Data Analysis (EDA)**:
#     - Distribution of genres
#     - Overview of key numerical and categorical features
#     - Basic visualizations to understand the relationships between different features and the target variable
#
# This notebook serves as the foundation for the subsequent steps in the project, providing insights and preparing the data for further analysis and model building.

# %%
import numpy as np
import pandas as pd

# %%
# Load the training data
train_path = "data/train_data.txt"
df = pd.read_csv(train_path, sep=':::', names=['title', 'genre', 'description'], engine='python')

# %%
df
# Out:
#                                               title          genre  \
# 1                     Oscar et la dame rose (2009)          drama
# 2                                     Cupid (1997)       thriller
# 3                 Young, Wild and Wonderful (1980)          adult
# 4                            The Secret Sin (1915)          drama
# 5                           The Unrecovered (2007)          drama
# ...                                             ...            ...
# 54210                              "Bonino" (1953)         comedy
# 54211                  Dead Girls Don't Cry (????)         horror
# 54212    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54213                     Make Your Own Bed (1944)         comedy
# 54214   Nature's Fury: Storm of the Century (2006)        history
#
#                                              description
# 1       Listening in to a conversation between his do...
# 2       A brother and sister with a past incestuous r...
# ...

# %%
df.shape
# Out:
# (54214, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54214 entries, 1 to 54214
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        54214 non-null  object
#  1   genre        54214 non-null  object
#  2   description  54214 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#                                  title    genre  \
# count                            54214    54214
# unique                           54214       27
# top      Oscar et la dame rose (2009)    drama
# freq                                 1    13613
#
#                                               description
# count                                               54214
# unique                                              54086
# top      Grammy - music award of the American academy ...
# freq                                                   12

# %%
df.isnull().sum()
# Out:
# title          0
# genre          0
# description    0
# dtype: int64

# %% [markdown]
# ## Basic Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,15))
sns.countplot(data=df, y="genre", order= df["genre"].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(27,7))
sns.countplot(data=df, x="genre", order= df["genre"].value_counts().index, palette = "YlGnBu")
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_5372\326227186.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="genre", order= df["genre"].value_counts().index, palette = "YlGnBu")

# %%
original_lengths = train_data['description'].apply(len)
plt.hist(original_lengths, bins=range(0, max(original_lengths) + 100, 100), color='blue', alpha=0.7)
plt.title('Original Text Length')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.to_csv("data/movie-genre-classification-train.csv", index=False)
