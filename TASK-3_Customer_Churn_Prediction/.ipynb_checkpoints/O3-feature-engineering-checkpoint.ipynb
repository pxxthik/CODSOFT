# %% [markdown]
# ## Feature Engineering
#
# ### Overview
# In this file, we focused on feature engineering to enhance the predictive power of the dataset for predicting bank customer churn.

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("data/Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ## Creating Features

# %%
# Combining location and gender
df['Geo_Gender'] = df['Geography'] + "_" + df['Gender']

# %%
# Extracting age groups
df['AgeGroup'] = df['Age'] // 10 * 10

# %%
# Age tenure interaction
df['Age_Tenure_Interaction'] = df['Age'] * df['Tenure']

# %%
# isSenior
df['IsSenior'] = df['Age'].apply(lambda x: 1 if x >= 65 else 0)

# %%
# Binerizing high balance
df['High_Balance'] = np.where(df['Balance'] > 125000, 1, 0)

# %%
# Balance to Salary ratio
df['Balance_to_Salary_Ratio'] = df['Balance'] / df['EstimatedSalary']

# %%
# Credit score binning
df['CreditScoreTier'] = pd.cut(df['CreditScore'], bins=[0, 650, 750, 850], labels=['Low', 'Medium', 'High'])

# %%
# Products to tenure ratio
df['Products_Per_Tenure'] = df['NumOfProducts'] / (df['Tenure'] + 0.0001)

# %%
# Aggregating tenure and NumOfProdcuts
df['Average_Product_Holding_Duration'] = df['Tenure'] / df['NumOfProducts']

# %%
# is Active credit card holder?
df['IsActive_by_CreditCard'] = df['HasCrCard'] * df['IsActiveMember']

# %%
# Costomer status
df['Customer_Status'] = df['Tenure'].apply(lambda x: 'New' if x < 2 else 'Long-term')

# %%
# Credit score with balance interaction
df['CreditScore_Balance_Interaction'] = df['CreditScore'] * df['Balance']

# %%
# Binarizing high credit score
df['High_CreditScore'] = np.where(df['CreditScore'] > 700, 1, 0)

# %%
# Aggregating Balance and NumOfProducts
df['Balance_per_Product'] = df['Balance'] / df['NumOfProducts']

# %%
df.sample(5)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 2229       2230    15756125      Booth          757     Spain    Male   44
# 5092       5093    15596303      White          688    France  Female   39
# 3273       3274    15646091  Frankland          560     Spain  Female   43
# 3789       3790    15765415       King          609     Spain  Female   45
# 1565       1566    15649523    Kennedy          581    France    Male   38
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2229       5  140856.16              2          1               0
# 5092       0       0.00              2          1               0
# 3273       4   95140.44              2          1               0
# 3789       4   89122.30              1          1               1
# 1565       1       0.00              2          1               0
#
#       EstimatedSalary  Exited     Geo_Gender  AgeGroup  \
# 2229        158735.10       0     Spain_Male        40
# 5092         53222.15       1  France_Female        30
# 3273        123181.44       1   Spain_Female        40
# 3789        199256.98       0   Spain_Female        40
# 1565         46176.22       0    France_Male        30
#
#       Age_Tenure_Interaction  IsSenior  High_Balance  Balance_to_Salary_Ratio  \
# 2229                     220         0             1                 0.887366
# 5092                       0         0             0                 0.000000
# 3273                     172         0             0                 0.772360
# 3789                     180         0             0                 0.447273
# 1565                      38         0             0                 0.000000
#
#      CreditScoreTier  Products_Per_Tenure  Average_Product_Holding_Duration  \
# 2229            High             0.399992                               2.5
# 5092          Medium         20000.000000                               0.0
# 3273             Low             0.499988                               2.0
# 3789             Low             0.249994                               4.0
# 1565             Low             1.999800                               0.5
#
#       IsActive_by_CreditCard Customer_Status  CreditScore_Balance_Interaction  \
# 2229                       0       Long-term                     1.066281e+08
# 5092                       0             New                     0.000000e+00
# 3273                       0       Long-term                     5.327865e+07
# 3789                       1       Long-term                     5.427548e+07
# 1565                       0             New                     0.000000e+00
#
#       High_CreditScore  Balance_per_Product
# 2229                 1             70428.08
# 5092                 0                 0.00
# 3273                 0             47570.22
# 3789                 0             89122.30
# 1565                 0                 0.00

# %%
# Drop unnecessary columns
df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (10000, 25)

# %%
df.sample(5)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 5983          619   Germany  Female   28       6   99152.73              2
# 9726          773     Spain    Male   43       7  138150.57              1
# 7700          752     Spain  Female   31       4  144637.86              2
# 6186          618    France    Male   37       5       0.00              1
# 4245          732    France  Female   34       8  122338.43              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited      Geo_Gender  \
# 5983          1               0         48475.12       0  Germany_Female
# 9726          1               1        177357.16       0      Spain_Male
# 7700          1               0         40496.72       0    Spain_Female
# 6186          0               1        178705.45       1     France_Male
# 4245          1               0        187985.85       0   France_Female
#
#       AgeGroup  Age_Tenure_Interaction  IsSenior  High_Balance  \
# 5983        20                     168         0             0
# 9726        40                     301         0             1
# 7700        30                     124         0             1
# 6186        30                     185         0             0
# 4245        30                     272         0             0
#
#       Balance_to_Salary_Ratio CreditScoreTier  Products_Per_Tenure  \
# 5983                 2.045435             Low             0.333328
# 9726                 0.778940            High             0.142855
# 7700                 3.571594            High             0.499988
# 6186                 0.000000             Low             0.199996
# 4245                 0.650785          Medium             0.249997
#
#       Average_Product_Holding_Duration  IsActive_by_CreditCard  \
# 5983                               3.0                       0
# 9726                               7.0                       1
# 7700                               2.0                       0
# 6186                               5.0                       0
# 4245                               4.0                       0
#
#      Customer_Status  CreditScore_Balance_Interaction  High_CreditScore  \
# 5983       Long-term                     6.137554e+07                 0
# 9726       Long-term                     1.067904e+08                 1
# 7700       Long-term                     1.087677e+08                 1
# 6186       Long-term                     0.000000e+00                 0
# 4245       Long-term                     8.955173e+07                 1
#
#       Balance_per_Product
# 5983            49576.365
# 9726           138150.570
# 7700            72318.930
# 6186                0.000
# 4245            61169.215

# %%
df.to_csv("data/churn_modelling_feature_engineering.csv", index=False)
